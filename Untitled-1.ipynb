# %%
# %reload_ext autoreload
# %autoreload 2


#This is needed to add the repo dir to the path so jupyter
# can load the republic modules directly from the notebooks
import os
import sys
import re
sys.path.append('/Users/rikhoekstra/develop/republic_clean/')

# from collections import defaultdict
import pandas as pd
from collections import Counter, defaultdict
import json
# import republic.model.republic_document_model as rdm

repo_dir = os.path.split(os.getcwd())[0]

if repo_dir not in sys.path:
    sys.path.append(repo_dir)
    
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')

# %%
import pandas as pd

# %%
webregent = pd.read_sql_table(con="mysql+pymysql://rik:X0chi@localhost/raa_web", table_name='regent')

# %%
newregent = pd.read_sql_table(con="mysql+pymysql://rik:X0chi@localhost/raa_out", table_name='persoon')

# %%
newregent.columns
# Out:
# Index(['persoon_id', 'id', 'index', 'idregent', 'geslachtsnaam',
#        'tussenvoegsel', 'idadellijketitel', 'idacademischetitel', 'voornaam',
#        'adel', 'adelspredikaat', 'heerlijkheid', 'heerlijkheid2',
#        'geboortejaar', 'onbepaaldgeboortedatum', 'overlijdensjaar',
#        'onbepaaldoverlijdensdatum', 'opmerkingen', 'periode', 'eindcontrole',
#        'old_idregent', 'old_idadellijketitel', 'old_idacademischetitel',
#        'geboortedag', 'geboortemaand', 'doopjaar', 'geboorteplaats',
#        'overlijdensdag', 'overlijdensmaand', 'overlijdensplaats', 'tempid',
#        'opmerkingen2', 'geboortedatum_als_bekend',
#        'overlijdensdatum_als_bekend', 'geboortedatum', 'overlijdensdatum',
#        'searchable', 'academischetitel_id', 'adellijketitel_id'],
#       dtype='object')

# %%
webregent.columns
# Out:
# Index(['id', 'adel', 'heerlijkheid', 'voornaam', 'tussenvoegsel',
#        'geslachtsnaam', 'searchable_geslachtsnaam', 'geboortedatum',
#        'geboortedatum_als_bekend', 'geboorteplaats', 'doopjaar',
#        'overlijdensdatum', 'overlijdensdatum_als_bekend', 'overlijdensplaats',
#        'adellijketitel_id', 'academischetitel_id', 'opmerkingen'],
#       dtype='object')

# %%
m = newregent.merge(webregent, left_on=['geslachtsnaam','voornaam'], right_on=['geslachtsnaam','voornaam'], how='outer')

# %%
m.loc[m.id_y.isna()]['geslachtsnaam','geslachts']
# Out:
#        persoon_id    id_x   index  idregent  \
# 0             1.0     1.0     0.0       1.0
# 1           110.0   110.0   109.0    2801.0
# 75           10.0    10.0     9.0    2701.0
# 178          15.0    15.0    14.0    2706.0
# 232          21.0    21.0    20.0     264.0
# ...           ...     ...     ...       ...
# 17292      6938.0  6938.0  6937.0    4998.0
# 17293      6939.0  6939.0  6938.0    4674.0
# 17294      6940.0  6940.0  6939.0    4895.0
# 17295      6941.0  6941.0  6940.0    4909.0
# 17296      6942.0  6942.0  6941.0    6632.0
#
#                                         geslachtsnaam tussenvoegsel_x  \
# 0                                               Röell
# 1                                               Röell
# 75                                            Anethan              d'
# 178                                Béthune Hesdigneul              de
# 232                              Drevon de Montargues              de
# ...                                               ...             ...
# 17292                  Lynden tot Onsteyn en Lantfort             van
# 17293  Essen tot Helbergen, Schaffelaer en Abbenbroek             van
# 17294                          Haersolte tot Staveren             van
# 17295                                      Riemsdijck             van
# 17296                                     Teschemaker
#
#        idadellijketitel  idacademischetitel  \
# 0                   3.0                 6.0
# 1                   9.0                 4.0
# 75                  9.0                 NaN
# 178                 7.0                 NaN
# 232                 1.0                 1.0
# ...                 ...                 ...
# 17292               1.0                 7.0
# 17293               1.0                 7.0
# 17294               3.0                 7.0
# 17295               1.0                 7.0
# 17296               1.0                 7.0
#
#                                                 voornaam  adel_x  ...  \
# 0                                        Willem Frederik     1.0  ...
# 1                                        Willem Frederik     1.0  ...
# 75                François Henri François de Paul Joseph     1.0  ...
# 178    Marie Amé Bernard Antoine Joseph Eugène Maximi...     1.0  ...
# 232                                   Daniël Jacob Adolf     1.0  ...
# ...                                                  ...     ...  ...
# 17292                                       Heilwig Derk     1.0  ...
# 17293                                       Lucas Willem     1.0  ...
# 17294                      Antony Frederik Robbert Evert     1.0  ...
# 17295                                              Dirck     0.0  ...
# 17296                                              Johan     0.0  ...
#
#       geboortedatum_y geboortedatum_als_bekend_y geboorteplaats_y  doopjaar_y  \
# 0                 NaT                        NaN              NaN         NaN
# 1                 NaT                        NaN              NaN         NaN
# 75                NaT                        NaN              NaN         NaN
# 178               NaT                        NaN              NaN         NaN
# 232               NaT                        NaN              NaN         NaN
# ...               ...                        ...              ...         ...
# 17292             NaT                        NaN              NaN         NaN
# 17293             NaT                        NaN              NaN         NaN
# 17294             NaT                        NaN              NaN         NaN
# 17295             NaT                        NaN              NaN         NaN
# 17296             NaT                        NaN              NaN         NaN
#
#        overlijdensdatum_y  overlijdensdatum_als_bekend_y  overlijdensplaats_y  \
# 0                     NaT                            NaN                  NaN
# 1                     NaT                            NaN                  NaN
# 75                    NaT                            NaN                  NaN
# 178                   NaT                            NaN                  NaN
# 232                   NaT                            NaN                  NaN
# ...                   ...                            ...                  ...
# 17292                 NaT                            NaN                  NaN
# 17293                 NaT                            NaN                  NaN
# 17294                 NaT                            NaN                  NaN
# 17295                 NaT                            NaN                  NaN
# 17296                 NaT                            NaN                  NaN
#
#       adellijketitel_id_y  academischetitel_id_y  opmerkingen_y
# 0                     NaN                    NaN            NaN
# 1                     NaN                    NaN            NaN
# 75                    NaN                    NaN            NaN
# 178                   NaN                    NaN            NaN
# 232                   NaN                    NaN            NaN
# ...                   ...                    ...            ...
# 17292                 NaN                    NaN            NaN
# 17293                 NaN                    NaN            NaN
# 17294                 NaN                    NaN            NaN
# 17295                 NaN                    NaN            NaN
# 17296                 NaN                    NaN            NaN
#
# [3434 rows x 54 columns]

# %%
m.loc[m.id_y.isin(ids)]
# Out:
# Empty DataFrame
# Columns: [persoon_id, id_x, index, idregent, geslachtsnaam, tussenvoegsel_x, idadellijketitel, idacademischetitel, voornaam, adel_x, adelspredikaat, heerlijkheid_x, heerlijkheid2, geboortejaar, onbepaaldgeboortedatum, overlijdensjaar, onbepaaldoverlijdensdatum, opmerkingen_x, periode, eindcontrole, old_idregent, old_idadellijketitel, old_idacademischetitel, geboortedag, geboortemaand, doopjaar_x, geboorteplaats_x, overlijdensdag, overlijdensmaand, overlijdensplaats_x, tempid, opmerkingen2, geboortedatum_als_bekend_x, overlijdensdatum_als_bekend_x, geboortedatum_x, overlijdensdatum_x, searchable, academischetitel_id_x, adellijketitel_id_x, id_y, adel_y, heerlijkheid_y, tussenvoegsel_y, searchable_geslachtsnaam, geboortedatum_y, geboortedatum_als_bekend_y, geboorteplaats_y, doopjaar_y, overlijdensdatum_y, overlijdensdatum_als_bekend_y, overlijdensplaats_y, adellijketitel_id_y, academischetitel_id_y, opmerkingen_y]
# Index: []
#
# [0 rows x 54 columns]

# %%
webregent.geslachtsnaam.str.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 webregent.geslachtsnaam.str.isascii()
#
# AttributeError: 'StringMethods' object has no attribute 'isascii'

# %%
mask = newregent['geslachtsnaam'].str.len()\
                 .ne(newregent['geslachtsnaam'].str.encode('ascii',errors = 'ignore').str.len())

# %%
new_nonasci = newregent[mask]

# %%
ascimasc = metnaam.geslachtsnaam.str.contains('RoÃ«ll',regex=True)

# %%
ascimasc
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 12093    False
# 12094    False
# 12095    False
# 12096    False
# 12097    False
# Name: geslachtsnaam, Length: 12097, dtype: bool

# %%
metnaam[ascimasc]
# Out:
#           id  adel heerlijkheid           voornaam tussenvoegsel  \
# 12091  12092     0               Dionysius Andreas          None
#
#       geslachtsnaam searchable_geslachtsnaam geboortedatum  \
# 12091        RoÃ«ll                   RoÃ«ll    1689-01-01
#
#       geboortedatum_als_bekend geboorteplaats  doopjaar overlijdensdatum  \
# 12091                     1689           None         0       1733-12-31
#
#       overlijdensdatum_als_bekend overlijdensplaats  adellijketitel_id  \
# 12091                        1733              None                NaN
#
#        academischetitel_id                                        opmerkingen
# 12091                  NaN  Overig: was hoogleraar wijsbegeerte aan het De...

# %%
metnaam = webregent.loc[webregent.geslachtsnaam.notna()]

# %%
mask = webregent['geslachtsnaam'].str.len()\
                 .ne(webregent['geslachtsnaam'].str.encode('ascii',errors = 'ignore').str.len())

# %%
nonascii = webregent.loc[mask]

# %%
nonascii['nas'] = nas

# %%
nas = nonascii.geslachtsnaam.str.encode('ascii', 'ignore').str.decode('ascii',errors='')

# %%
nns = new_nonasci.geslachtsnaam.str.encode('ascii', 'ignore').str.decode('ascii')

# %%
new_nonasci['nns'] = nns

# %%
pd.DataFrame(nns).merge(pd.DataFrame(nas))
# Out:
#            geslachtsnaam
# 0                   Rell
# 1                   Rell
# 2                   Rell
# 3                   Rell
# 4                   Rell
# ..                   ...
# 641                 Nere
# 642                 Nere
# 643            Prvinaire
# 644                Honor
# 645  Brutel de la Rivire
#
# [646 rows x 1 columns]

# %%
nonascii.merge(new_nonasci, left_on='nas',right_on='nns',how='outer').to_csv('/Users/rikhoekstra/surfdrive/Republic/controle_asci_regent',sep='\t')
