# %%
# %reload_ext autoreload
# %autoreload 2


#This is needed to add the repo dir to the path so jupyter
# can load the republic modules directly from the notebooks
import os
import sys
import re
sys.path.append('/Users/rikhoekstra/develop/republic_clean/')

# from collections import defaultdict
import pandas as pd
from collections import Counter, defaultdict
import json
# import republic.model.republic_document_model as rdm

repo_dir = os.path.split(os.getcwd())[0]

if repo_dir not in sys.path:
    sys.path.append(repo_dir)
    
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')

# %%
import pandas as pd

# %%
webregent = pd.read_sql_table(con="mysql+pymysql://rik:X0chi@localhost/raa_web", table_name='regent')

# %%
newregent = pd.read_sql_table(con="mysql+pymysql://rik:X0chi@localhost/raa_nw", table_name='persoon')

# %%
newregent.columns
# Out:
# Index(['geslachtsnaam', 'tussenvoegsel', 'voornaam', 'adel', 'adelspredikaat',
#        'heerlijkheid', 'geboortejaar', 'overlijdensjaar', 'opmerkingen',
#        'periode', 'eindcontrole', 'geboortedag', 'geboortemaand', 'doopjaar',
#        'geboorteplaats', 'overlijdensdag', 'overlijdensmaand',
#        'overlijdensplaats', 'id', 'geboortedatum', 'overlijdensdatum',
#        'searchable', 'academischetitel_id', 'adellijketitel_id', '1', '2', '3',
#        '4', '5'],
#       dtype='object')

# %%
webregent.columns
# Out:
# Index(['id', 'heerlijkheid', 'adelspredikaat', 'voornaam', 'tussenvoegsel',
#        'geslachtsnaam', 'geboortejaar', 'geboortejaar_als_bekend',
#        'overlijdensjaar', 'overlijdensjaar_als_bekend', 'adellijketitel_id',
#        'academischetitel_id'],
#       dtype='object')

# %%
cols = ['geslachtsnaam','tussenvoegsel','voornaam','heerlijkheid']

# %%
nr = newregent.copy()
wr = webregent.copy()
for c in cols:
    for r in [nr, wr]:
        r[c] = r[c].astype(str)
        r[c] = r[c].str.replace('None','')
        r[c] = r[c].str.strip()

# %%
# Out:
# 0       AerssenvanVosholvanCornelisVoshol
# 1                       FremerydeNicolaas
# 2                     ThileniusJanAbraham
# 3                MeervanderJacobHoogeveen
# 4               JosseletCoenraadHendriksz
#                       ...
# 7984                            KingmaJan
# 7985         HagedoornHermannusGijsbertsz
# 7986                  BlomvanAssendelftCJ
# 7987                                KoolJ
# 7988                 HaersmavanArentAulus
# Name: concat, Length: 7989, dtype: object

# %%
for r in [nr, wr]:
    r['concat'] = r[cols].agg(''.join,axis=1)
    r['concat'] = r['concat'].str.replace('\W','',regex=True)

# %%
wr['concat']
# Out:
# 0       AerssenvanVosholvanCornelisVoshol
# 1                       FremerydeNicolaas
# 2                     ThileniusJanAbraham
# 3                MeervanderJacobHoogeveen
# 4               JosseletCoenraadHendriksz
#                       ...
# 7984                            KingmaJan
# 7985         HagedoornHermannusGijsbertsz
# 7986                  BlomvanAssendelftCJ
# 7987                                KoolJ
# 7988                 HaersmavanArentAulus
# Name: concat, Length: 7989, dtype: object

# %%
nr
# Out:
#                                         geslachtsnaam   tussenvoegsel  \
# 0                                               Röell
# 1                                            Mollerus
# 2                                   Lodewijk Napoleon
# 3                                           Crommelin  van Wickevoort
# 4                                            Appelius
# ...                                               ...             ...
# 47320  Essen tot Helbergen, Schaffelaer en Abbenbroek             van
# 47321                          Haersolte tot Staveren             van
# 47322                                      Riemsdijck             van
# 47323                                     Teschemaker
# 47324                                           Drept         van der
#
#                             voornaam  adel adelspredikaat  \
# 0                    Willem Frederik     1           None
# 1                      Johan Hendrik     1           None
# ...

# %%
m = nr.merge(wr, left_on='concat', right_on='concat', how='right', suffixes=['_nr','_wr'])

# %%
m
# Out:
#          geslachtsnaam_nr tussenvoegsel_nr  voornaam_nr  adel  \
# 0      Aerssen van Voshol              van     Cornelis   1.0
# 1      Aerssen van Voshol              van     Cornelis   1.0
# 2      Aerssen van Voshol              van     Cornelis   1.0
# 3                 Fremery               de     Nicolaas   0.0
# 4                 Fremery               de     Nicolaas   0.0
# ...                   ...              ...          ...   ...
# 26659             Haersma              van  Arent Aulus   0.0
# 26660             Haersma              van  Arent Aulus   0.0
# 26661             Haersma              van  Arent Aulus   0.0
# 26662             Haersma              van  Arent Aulus   0.0
# 26663             Haersma              van  Arent Aulus   0.0
#
#       adelspredikaat_nr heerlijkheid_nr  geboortejaar_nr  overlijdensjaar_nr  \
# 0                  None          Voshol           1698.0              1766.0
# ...

# %%
concordance = m.loc[m['id_nr'].notna()][['id_nr','id_wr']].drop_duplicates('id_wr')

# %%
m.loc[m['id_nr'].isna()]['concat']
# Out:
# 114            TwentvanGelÃAbrahamCatharinusKortenbosch
# 208                    BoogertFranÃoisFranÃoiszFranÃois
# 281                             OostenvanGabriÃlLeonard
# 366                       BrandelervandenJohanFranÃoisz
# 415             BurchvanderJohanFranÃoiszNiemandsvriend
#                               ...
# 26446                                     BlocqdeDaniÃl
# 26447    BÃnninghausentotDarupvonClemensMariaFranciscus
# 26469                     JannessonSÃbastienLouisJoseph
# 26494                                DucelliÃEverhardus
# 26648                               BlomvanAssendelftCJ
# Name: concat, Length: 495, dtype: object

# %%
m.loc[m.id_nr.isna()][[c+'_wr' for c in cols]+['concat','id_wr']].drop_duplicates(['geslachtsnaam_wr'])
# Out:
#           geslachtsnaam_wr tussenvoegsel_wr          voornaam_wr  \
# 6                Thilenius             None          Jan Abraham
# 13                Josselet             None  Coenraad Hendriksz.
# 23                 Rendorp             None              Joachim
# 24                   Dedel             None              Abraham
# 28               Beelaerts             None               Gerard
# ...                    ...              ...                  ...
# 15671          Romswinckel             None                Joost
# 15672          Spijkermans             None                   A.
# 15673         Tonneboeijer             None                Jacob
# 15698           Cuylenburg             None             Johannes
# 15709  Blom van Assendelft             None                 C.J.
#
#                             heerlijkheid_wr  \
# 6
# 13
# 23                                Marquette
# 24
# 28     Blokland en Wieldrecht en Dortsmonde
# ...

# %%
from pylcs import levenshtein_distance
def score_lcsr(term1, term2):
    max_distance = max(len(term1),len(term2))
    distance = levenshtein_distance(term1, term2)
    return 1 - distance / max_distance

# %%
def srch2df(skipgramsearcher=None, 
            lst=[], 
            dataframe=None, 
            src_column='', 
            target_column='', 
            threshold=0.5):
    df=dataframe
    res = {w:skipgramsearcher.rank_similar(w) for w in lst}
    redux_res = multiples_to_single(res, threshold=threshold)
    rr = {k:v[0] for k,v in redux_res.items()}
    df[target_column] = df[src_column].map(rr)
    df[[f'{target_column}_loc', f'{target_column}_score']] = df[target_column].apply(pd.Series)
    return df

# %%
mask = newregent['geslachtsnaam'].str.len()\
                 .ne(newregent['geslachtsnaam'].str.encode('ascii',errors = 'ignore').str.len())

# %%
new_nonasci = newregent[mask]

# %%
ascimasc = metnaam.geslachtsnaam.str.contains('RoÃ«ll',regex=True)

# %%
ascimasc
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 12093    False
# 12094    False
# 12095    False
# 12096    False
# 12097    False
# Name: geslachtsnaam, Length: 12097, dtype: bool

# %%
metnaam[ascimasc]
# Out:
#           id  adel heerlijkheid           voornaam tussenvoegsel  \
# 12091  12092     0               Dionysius Andreas          None
#
#       geslachtsnaam searchable_geslachtsnaam geboortedatum  \
# 12091        RoÃ«ll                   RoÃ«ll    1689-01-01
#
#       geboortedatum_als_bekend geboorteplaats  doopjaar overlijdensdatum  \
# 12091                     1689           None         0       1733-12-31
#
#       overlijdensdatum_als_bekend overlijdensplaats  adellijketitel_id  \
# 12091                        1733              None                NaN
#
#        academischetitel_id                                        opmerkingen
# 12091                  NaN  Overig: was hoogleraar wijsbegeerte aan het De...

# %%
metnaam = webregent.loc[webregent.geslachtsnaam.notna()]

# %%
mask = webregent['geslachtsnaam'].str.len()\
                 .ne(webregent['geslachtsnaam'].str.encode('ascii',errors = 'ignore').str.len())

# %%
nonascii = webregent.loc[mask]

# %%
nonascii['nas'] = nas

# %%
nas = nonascii.geslachtsnaam.str.encode('ascii', 'ignore').str.decode('ascii',errors='')

# %%
nns = new_nonasci.geslachtsnaam.str.encode('ascii', 'ignore').str.decode('ascii')

# %%
new_nonasci['nns'] = nns

# %%
pd.DataFrame(nns).merge(pd.DataFrame(nas))
# Out:
#            geslachtsnaam
# 0                   Rell
# 1                   Rell
# 2                   Rell
# 3                   Rell
# 4                   Rell
# ..                   ...
# 641                 Nere
# 642                 Nere
# 643            Prvinaire
# 644                Honor
# 645  Brutel de la Rivire
#
# [646 rows x 1 columns]

# %%
nonascii.merge(new_nonasci, left_on='nas',right_on='nns',how='outer').to_csv('/Users/rikhoekstra/surfdrive/Republic/controle_asci_regent',sep='\t')
